# %%
import json
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
url = "https://kingoinfo.skku.edu/gaia/nxui/index.html?ticket=GVVsR0gJcOQeScyA"
browser = webdriver.Chrome()
browser.get(url)
browser.implicitly_wait(3)
sleep(13)
# 로그인 수동으로 하기
# sleep(13)

# %%
browser.find_element(
    By.XPATH,
    "/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[1]/div/div/div/div[2]/div/div/div/div[16]/div/div[1]/input",
).send_keys("전체과목 검색")
browser.find_element(
    By.XPATH,
    "/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[1]/div/div/div/div[2]/div/div/div/div[16]/div/div[1]/input",
).send_keys(Keys.ENTER)
browser.implicitly_wait(3)

# %%
subjectmap = {"고전명저":"GEDM","글로벌":"GEDG","인성":"GEDC","리더쉽":"GEDR","의사소통":"GEDW","창의":"GEDT","BSM":"GEDB","기인사":"GEDI","핵균-인간-문화":"GEDH","핵균-사회-역사":"GEDS","핵균-자연-과학-기술":"GEDN","일반선택":"GELT"}

# %%
for idx ,value in subjectmap.items():
    browser.find_element(By.XPATH, "/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[3]/div/div/div/div[9]/input").click()
    sleep(1)
    browser.find_element(By.XPATH, "/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[3]/div/div/div/div[9]/input").clear()
    sleep(1)
    browser.find_element(By.XPATH, "/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[3]/div/div/div/div[9]/input").send_keys(value)
    
    print(key)
    browser.find_element(By.XPATH,"/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[3]/div/div/div/div[8]/div").click()
    sleep(2)
# Out:
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택
# 일반선택

# %%
for h in range(60): 
    table = browser.find_elements(By.XPATH, "/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[2]/div[1]/div[2]/div/div/div")
    duplicated = 0
    for tab in table:
        result = [] 
        a = tab.text.split("\n")
        if len(a) <= 8:
            continue
        if a in result:
            duplicated += 1
        else:
            print(a)
            result.append(a)

    
    if duplicated > 4:
        break
    scroll = browser.find_element(By.XPATH,"/html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[2]/div[3]/div/div[2]/div")
    if scroll.is_displayed():
        for _ in range(10):
            scroll.click()
        sleep(2)
    else:
        break

# /html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[2]/div[1]/div[2]/div/div/div[2]/div/div
# /html/body/div/div[1]/div/div/div[1]/div/div/div/div/div/div[3]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div[3]/div/div[2]/div[1]/div[2]/div/div/div[3]
# Out:
# ['담기', 'GEDG002-41', '교양', '영어발표', 'English Presentation', '저스틴바라스', '보기', '자연', '학사', '월09:00-10:15【51209】,수10:30-11:45【51209】', '국제어수업', '2(3)', '오프라인']
# ['담기', 'GEDG002-42', '교양', '영어발표', 'English Presentation', '저스틴바라스', '보기', '자연', '학사', '월10:30-11:45【51209】,수09:00-10:15【51209】', '국제어수업', '2(3)', '오프라인']
# ['담기', 'GEDG002-43', '교양', '영어발표', 'English Presentation', '저스틴바라스', '보기', '자연', '학사', '월12:00-13:15【51209】,수13:30-14:45【51209】', '국제어수업', '2(3)', '오프라인']
# ['담기', 'GEDG002-44', '교양', '영어발표', 'English Presentation', '저스틴바라스', '보기', '자연', '학사', '월13:30-14:45【51209】,수12:00-13:15【51209】', '국제어수업', '2(3)', '오프라인']
# ['담기', 'GEDG002-46', '교양', '영어발표', 'English Presentation', '윌리암히슬롭', '보기', '자연', '학사', '월10:30-11:45【61351B】,수09:00-10:15【61351B】', '국제어수업', '2(3)', '오프라인']
# ['담기', 'GEDG002-47', '교양', '영어발표', 'English Presentation', '윌리암히슬롭', '보기', '자연', '학사', '월12:00-13:15【61351B】,수13:30-14:45【61351B】', '국제어수업', '2(3)', '오프라인']
# ...
