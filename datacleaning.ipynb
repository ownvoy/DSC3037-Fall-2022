# %%
import json, pandas as pd

# %%
import json, pandas as pd
with open(r'D:\DSC3037\data\의예과\2022학년도 2학기.json',encoding='UTF8') as f:
    js = json.loads(f.read()) ## json 라이브러리 이용
df1 = pd.DataFrame(js)
df1 = pd.read_json(r'D:\DSC3037\data\의예과\2022학년도 2학기.json',encoding='UTF8') ## pd.read_json 이용
df2_list = df1['course'].to_list()

# 보기 삭제
for each in df2_list:
    for i in range(len(each)):
        if each[i]== '보기':
            idx = i
            each.remove(each[idx])
            break

# 영역구분 3 만들어 주기
for each in df2_list:
    if each[1] == '전공코어' or each[1] == '전공심화' or each[1] == '실험실습':
        continue
    else:
        each.insert(1,'nan')

# 교수님 이름 없을때
for each in df2_list:
    if each[5] == "인문사회" or each[5] == "자연과학":
        each.insert(5,'nan')

# 수업방식2
for each in df2_list:
    if len(each) == 11:
        each.append('nan')

# 13번째 collumn은 비고 칸
for each in df2_list:
    if len(each) == 12:
        each.append('nan')

courselist = ["온라인 (사전제작)", 
                            "온라인 (사전제작+Real Time Streaming)",
                            "온라인 (Real Time Streaming)",
                            "온-오프혼합 (오프라인 순환출석+Real Time Streaming)",
                            "온-오프혼합 (오프라인+Real Time Streaming)",
                            "온-오프혼합 (오프라인+강의저장)",
                            "온-오프[오프라인+강의저장]",
                            "온-오프[오프라인+Real Time Streaming]",
                            "오프라인", 
                            "오프라인 (일부 주차 오프라인+잔여 주차 Real Time Streaming)",
                            "오프라인 (일부 주차 오프라인+잔여 주차 사전제작영상)",
                            "온-오프혼합 (오프라인 순환출석+강의저장)",
                            "글로벌-혁신[온라인사전강의 + 오프라인 또는 온라인 Real Time Streaming",
                            "nan"]

for each in df2_list:
    count = 0
    for class_way in  courselist:
        if each[-2] == class_way:
            count = 1
    if count == 0:
        temp = each[-2]
        each[-1] = temp    
        each[-2] = 'nan'    
# df2_ list를 dataframe으로
df1['course'] = df2_list

collumnName = ['degree_courses',
                                    'type_of_field3',
                                    'course_code',
                                    'course_title',
                                    'course_title_english',
                                    'instructor',
                                    'campus',
                                    'type_of_field2',
                                    'credits(Hrs)',
                                    'classtime',
                                    'type_of_class1',
                                    'type_of_class2',
                                    'remarks']
                                    

for idx, name in  enumerate(collumnName):
    df1[name] = df1['course'].str.get(idx)



df1=df1.drop(['course'], axis='columns')
pd.set_option('display.max_rows',None)
df1
# Out:
#   major     semester college degree_courses type_of_field3 course_code  \
# 0   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2028-41
# 1   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2031-41
# 2   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2032-41
# 3   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2035-41
# 4   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2032-41
# 5   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2033-41
# 6   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2035-41
# 7   의예과  2022학년도 2학기    의과대학             학사           전공코어  MED2037-41
#
#    course_title                               course_title_english  \
# 0  인체대사와세포조절및실험  Cell Biology Part and Human Metabolism and Exp...
# 1      인체의구조와발생            Structure and Development of Human Body
# 2    인체의미세구조와기능                                                nan
# 3         인문과인간             A Journey to Understanding Human Being
# 4    인체의미세구조와기능   Microscopic Structure and Function of Human Body
# 5         인체의기능                                   Human Physiology
# 6         인문과인간             A Journey to Understanding Human Being
# 7          인문과삶              A Journey to Understanding Human Life
#
#                                          instructor campus type_of_field2  \
# 0                                               배창대   자연과학           전공핵심
# 1                                               김문영   자연과학           전공핵심
# 2  Microscopic Structure and Function of Human Body    NaN            NaN
# 3                                               주경민   자연과학           전공일반
# 4                                               주경민   자연과학           전공핵심
# 5                                               강동묵   자연과학           전공핵심
# 6                                               주경민   자연과학           전공일반
# 7                                               한태희   자연과학           전공일반
#
#   credits(Hrs)                                          classtime  \
# 0         5(5)  화09:00-09:50【711112】,화10:00-10:50【711112】,화11:...
# 1         5(5)  수09:00-09:50【711112】,수10:00-10:50【711112】,수11:...
# 2          NaN                                                NaN
# 3         2(2)          월15:00-15:50【711101】,월16:00-16:50【711101】
# 4         3(3)  수13:00-13:50【711112】,수14:00-14:50【711112】,수15:...
# 5         4(4)  월13:00-13:50【711112】,월14:00-14:50【711112】,금13:...
# 6         2(2)          월15:00-15:50【711101】,월16:00-16:50【711101】
# 7         2(2)          월10:00-10:50【711112】,월11:00-11:50【711112】
#
#   type_of_class1                                    type_of_class2  remarks
# 0           일반수업                                              오프라인  M2 수강과목
# 1           일반수업  글로벌-혁신[온라인사전강의 + 오프라인 또는 온라인 Real Time Streaming      nan
# 2            NaN                                               NaN      NaN
# 3           일반수업                                              오프라인      nan
# 4           일반수업                                              오프라인  M2 수강과목
# 5           일반수업                                              오프라인  M2 수강과목
# 6           일반수업                                              오프라인  M1 수강과목
# 7           일반수업                                              오프라인  M2 수강과목
